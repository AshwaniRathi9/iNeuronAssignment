# %% [markdown]
# 1: Create two int type variables, apply addition, subtraction, division and multiplications and store the results in variables. Then print the data in the following format by calling the variables:
#
# :-

# %%
#Addition
add = 5 + 2
print ("Addition: %d" %add)

#Subtraction
sub = 5 - 2
print ("Subtraction: %d" %sub)

#Multiplication
mul = 5 * 2
print ("Multiplication: %d" %mul)

#Division
div = 5 / 2
print ("Division: %.2f" %div)
# Out:
# Addition: 7
# Subtraction: 3
# Multiplication: 10
# Division: 2.50

# %% [markdown]
# 2: What is the difference between the following operators: (i) ‘/’ & ‘//’ (ii) ‘**’ & ‘^’
#
# :- 1, 5 / 2 will return 2.5 and 5 // 2 will return 2
#    2,

# %%
a=4
b=2
x=a//b

print(x)
# Out:
# 2

# %%
a=10
b=5
x=a/b
print(x)
# Out:
# 2.0

# %% [markdown]
# 3:- List the logical operators.
#
# :- AND,OR, NOT

# %% [markdown]
# 4:- Explain right shift operator and left shift operator with examples.
#
# :- The bitwise shift operators are the right-shift operator (>>), which moves the bits of an integer or enumeration type expression to the right, and the left-shift operator (<<), which moves the bits to the left.

# %% [markdown]
# 5:- Create a list containing int type data of length 15. Then write a code to check if 10 is
# present in the list or not.
#
# :- Is it possible to create a list of integers with a single line of code, without using any third-party libraries?

# %%
lst = list(int(1,2,3,4))
